# %%
"""Exploring the original data and model results"""

# Custom modules
import util.reviews as reviews
import util.viz as viz

# %%
text_reviews, star_reviews = reviews.get_reviews()

# %%
# Star Distribution of Text Reviews vs. Star Distribution of Non-Text Reviews
viz.get_cumulative_review_plot(text_reviews, star_reviews)

# %%
# Are customers more likely to leave a text review when they are angry (1-star) or happy (5-star)?
viz.get_star_review_pie_plot(text_reviews)
